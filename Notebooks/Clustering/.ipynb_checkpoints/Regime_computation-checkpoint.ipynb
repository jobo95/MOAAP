# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from sklearn import decomposition, cluster
import xarray as xr
import os
from src.clustering.clustering_utils import *
from src.Enumerations import Season, Experiments

#%run /work/aa0238/a271093/Scripts/MOAAP/src/clustering/clustering_preprocess_data.py
# Out:
# /work/aa0238/a271093/Conda/MOAAP_env/lib/python3.12/site-packages/pyproj/__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %%
exp.exp_name
# Out:
# 'NORESM_ICON_control'

# %%
exp = Experiments.ICON_NORESM_CONTROL.value
season = Season.DJF
year_start = exp.year_start
year_end = exp.year_end
slp_nc = "zg"
lon_nc = 'lon'  
lat_nc = 'lat' 
time_nc = 'time' 

path_in = exp.clustering_data_path
#file_name = f'NORESM_ICON_control_gph50000_1984_2014_reglonlat_0_360_20_88_1125deg_{season.name}_fldmean_detrend_aac.nc'  # Area selected,  29feb deleted, all months !!!!!!
file_name = f'{exp.exp_name}_gph50000_1984_2014_reglonlat_-90_90_20_88_1deg_{season.name}_fldmean_detrend_del29feb_aac.nc'


DO_reduce_dim = 1  #reduce dimensionality before applying clustering
DO_cosine_cor = 1     #DO cosine correction to data before applying clustering 
                      #and transorm back afterwards


if DO_reduce_dim:
    n_components = 20  #dimensionality of reduced phase space

##################
#kmeans parameter#
##################
num_cluster = 5
num_iter = 50     # initiate algorithm n_times randomly and pick best result
random_state = 42   #reandom seed for reproducibility

# %%
data_xr =xr.load_dataset(path_in+file_name)
data_aux = np.squeeze(data_xr.zg.values)

# %%
data_ar = np.reshape(data_aux,(data_aux.shape[0], data_aux.shape[1]*data_aux.shape[2]))

# %%
lat = data_xr.lat.values
lon = data_xr.lon.values
time_frame = data_xr.time.values

# %%
data_ar.shape
# Out:
# (2790, 9821)

# %%
lat
# Out:
# array([87.54057743, 86.41658314, 85.29252808, 84.16844735, 83.0443534 ,
#        81.92025174, 80.79614519, 79.67203535, 78.54792319, 77.42380933,
#        76.2996942 , 75.17557807, 74.05146116, 72.92734362, 71.80322558,
#        70.67910712, 69.5549883 , 68.43086919, 67.30674982, 66.18263024,
#        65.05851047, 63.93439054, 62.81027047, 61.68615027, 60.56202996,
#        59.43790955, 58.31378905, 57.18966847, 56.06554782, 54.94142711,
#        53.81730634, 52.69318552, 51.56906465, 50.44494373, 49.32082278,
#        48.19670179, 47.07258076, 45.94845971, 44.82433862, 43.70021751,
#        42.57609637, 41.45197521, 40.32785403, 39.20373283, 38.07961161,
#        36.95549038, 35.83136913, 34.70724786, 33.58312658, 32.45900529,
#        31.33488398, 30.21076267, 29.08664134, 27.96252001, 26.83839866,
#        25.71427731, 24.59015595, 23.46603458, 22.3419132 , 21.21779182,
#        20.09367043])

# %%
if DO_cosine_cor:
    data_ar =  cosine_cor(data_ar,lat,lon)
data_ar
# Out:
# 161
# array([[ 67.77801 ,  67.85463 ,  67.93254 , ..., -22.61287 , -21.556625,
#         -20.088264],
#        [ 76.66986 ,  76.684944,  76.69896 , ..., -46.787937, -43.01255 ,
#         -39.564846],
#        [ 67.07632 ,  66.82138 ,  66.56635 , ..., -60.619804, -58.6559  ,
#         -56.615395],
#        ...,
#        [ 62.174427,  61.916714,  61.65523 , ...,  38.70755 ,  38.94562 ,
#          38.832146],
#        [ 56.329235,  56.037106,  55.742428, ...,  28.071325,  29.500055,
#          30.99036 ],
#        [ 32.170067,  31.83766 ,  31.502272, ...,  10.070291,  11.104472,
#          11.887154]], dtype=float32)

# %%
if DO_reduce_dim:
    pca = decomposition.PCA(n_components=n_components)
    pca.fit(data_ar)
    data_ar = pca.transform(data_ar)

# %%
#####################
#######          ####
###### KMeans    ####
#####################


means = cluster.KMeans(n_clusters=num_cluster,
                n_init=num_iter,
                max_iter=900 ,
                random_state = random_state,
                algorithm='lloyd').fit(data_ar)
cluster_centers = means.cluster_centers_
plot_len = num_cluster
BMU = means.labels_

# %%
if DO_reduce_dim:
    cluster_centers = pca.inverse_transform(cluster_centers)

# %%
if DO_cosine_cor:
    cluster_centers = inv_cosine_cor(cluster_centers,lat,lon)

# %%
plot_dat = cluster_centers.reshape(-1,lat.size,lon.size)
cluster_names = np.arange(5)

fig_cluster = plot_cluster(plot_dat,lat,lon,
                            plot_size=(35, 15),
                            plot_shape=[1,5],
                            cbar_size=1,
                            cbar_ticks=np.arange(-100,100,20),
                            font_size=17,
                            unit='hPa',
                            color_lev = np.arange(-100,100,10),
                            titles =np.arange(5))

# %%
cluster_centers
# Out:
# array([[ 9.67103   ,  9.690021  ,  9.708751  , ...,  0.1338753 ,
#          0.1158597 ,  0.09717723],
#        [ 0.75498253,  0.74455583,  0.7344203 , ..., -0.23030935,
#         -0.22048874, -0.21264502],
#        [ 3.2873585 ,  3.2942374 ,  3.3011014 , ..., -0.13666174,
#         -0.13249813, -0.12473302],
#        [-5.309883  , -5.3067713 , -5.3037257 , ..., -0.23549578,
#         -0.24949758, -0.27072904],
#        [-5.8893204 , -5.903964  , -5.918561  , ...,  0.42337236,
#          0.43983755,  0.46280068]], dtype=float32)

# %%
cluster_dic= {3:"SCAN" , 4 : "NAO+" , 0 : "NAO-", 1 : "ATL-", 2 : "DIP"}
cluster_names = list(cluster_dic.keys())
BMU_bak = np.copy(BMU)
BMU[BMU_bak==cluster_names[0]] = 0
BMU[BMU_bak==cluster_names[1]] = 1
BMU[BMU_bak==cluster_names[2]] =2
BMU[BMU_bak==cluster_names[3]] = 3
BMU[BMU_bak==cluster_names[4]] = 4

# %%
BMU
# Out:
# array([4, 4, 4, ..., 4, 4, 4], dtype=int32)

# %%
list(cluster_dic.values())
# Out:
# ['SCAN', 'NAO+', 'NAO-', 'ATL-', 'DIP']

# %%
BMU_df = pd.DataFrame(BMU, index=time_frame)
BMU_df.columns=["cluster_id"]

BMU_df["cluster_name"] = BMU_df.apply(lambda row: list(cluster_dic.values())[row.cluster_id], axis=1)

# %%
BMU_df.to_csv()
# Out:
#             cluster_id cluster_name
# 1979-01-01           4          DIP
# 1979-01-02           4          DIP
# 1979-01-03           4          DIP
# 1979-01-04           4          DIP
# 1979-01-05           1         NAO+
# ...                ...          ...
# 2018-12-27           4          DIP
# 2018-12-28           4          DIP
# 2018-12-29           4          DIP
# 2018-12-30           4          DIP
# 2018-12-31           4          DIP
#
# [3600 rows x 2 columns]

# %%
apply(lambda row: row.a + row.b, axis=1)
# Out:
#             cluster_id
# 1979-01-01           4
# 1979-01-02           4
# 1979-01-03           4
# 1979-01-04           4
# 1979-01-05           1
# ...                ...
# 2018-12-27           4
# 2018-12-28           4
# 2018-12-29           4
# 2018-12-30           4
# 2018-12-31           4
#
# [3600 rows x 1 columns]
