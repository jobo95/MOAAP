# %% [markdown]
# # Plot PDFs for different IVT attributes for ERA5 over the regional ICON domain (1979-2021)

# %%
# %load_ext autoreload
# %autoreload 2
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import datetime
import cartopy
from metpy.units import units
import cartopy.crs as ccrs
import pickle
import os
import seaborn as sns


from src.utils import load_pkl, create_datetime_lists, get_datetime_str
from src.Enumerations import Month, Season
from src.xarray_util import create_obj_from_dict,  ObjectContainer
# Out:
# /work/aa0238/a271093/Conda/MOAAP_env/lib/python3.12/site-packages/pyproj/__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()
# /work/aa0238/a271093/Scripts/MOAAP/src/xarray_util.py:177: AccessorRegistrationWarning: registration of accessor <class 'src.xarray_util.Accessor'> under name 'get' for type <class 'xarray.core.dataset.Dataset'> is overriding a preexisting attribute with the same name.
#   @xr.register_dataset_accessor("get")

# %% [markdown]
# # Settings

# %%
input_path = '/work/aa0238/a271093/results/MOAAP/Cyclone_Tracking/ERA5_ICON_remapped_3x/'
type_='CY'
input_file_name_temp = 'MOAPP_ERA5_remapped_3x'
#input_field_grid= '/work/aa0238/a271093/data/input/IVT_85_percentiles_CNMR_control_3dx3dy.nc'
#GridPoint.input_field_grid = input_field_grid

first_year = 1979
last_year = 1986
num_years = last_year-first_year

# %% [markdown]
# ## Load pickle dictionaries into in-memory Datasets

# %%
# create datetime lists
start_date_list, end_date_list = create_datetime_lists(first_year,last_year, months=6, correct_last_endtime=False) 
first_processed_date = start_date_list[0]
last_processed_date = end_date_list[-1]


# create and append Tracking objects to list
IVTobj_ls=ObjectContainer([])

for start_date, end_date in zip(start_date_list, end_date_list):
    print(start_date)
    pickle_file_path = f'{input_path}{type_}_{input_file_name_temp}_{get_datetime_str(start_date)}-{get_datetime_str(end_date)}_corrected'
    
    dict_ = load_pkl(pickle_file_path)
    

    for object_id in dict_.keys():
        try:
            ds = create_obj_from_dict(dict_,
                                      object_id,
                                      load_coordinates=False
                                  
                                     )
        except ValueError as ex:
            continue
        
        IVTobj_ls.append(ds)
# Out:
# 1979-01-01 00:00:00
# 1979-07-01 00:00:00
# 1980-01-01 00:00:00
# 1980-07-01 00:00:00
# 1981-01-01 00:00:00
# 1981-07-01 00:00:00
# 1982-01-01 00:00:00
# 1982-07-01 00:00:00
# 1983-01-01 00:00:00
# 1983-07-01 00:00:00
# 1984-01-01 00:00:00
# 1984-07-01 00:00:00
# 1985-01-01 00:00:00
# 1985-07-01 00:00:00

# %% [markdown]
# # Total number of IVT-object occurrences in ERA5 per season over domain

# %%
fig, ax = plt.subplots()

seasons = [x.name for x in Season]
colors = ['blue', 'darkgreen', 'red', 'yellow']


counts=[]
for season_ in Season:
    counts.append((IVTobj_ls.sel_season(season=season_).count())/num_years)

    
ax.bar(seasons, counts, color=colors)

ax.set_ylabel('IVT count per season')
ax.set_title('Total count of IVT occurrences over entire domain')
# Out:
# Text(0.5, 1.0, 'Total count of IVT occurrences over entire domain')

# %% [markdown]
# # Duration of Cyclone-objects

# %%
fig, ax = plt.subplots()
range_=(12,180)
for i,season_ in enumerate(Season):

    dat=IVTobj_ls.sel_season(season=season_).get_attributes(attr='duration')##obj_means("size")

    sns.histplot(dat,label=season_.name,alpha=1-(i*0.23),color=colors[i],bins=58, binrange=range_, stat='density')

ax.set_xlabel('Object duration [hrs]')
ax.set_ylabel('Probability density')
plt.legend()
plt.grid()
ax.set_xlim(range_)
# Out:
# (12.0, 180.0)

# %% [markdown]
# # Median Size of Cyclone-objects

# %%
fig, ax = plt.subplots()

for i,season_ in enumerate(Season):


    dat=IVTobj_ls.sel_season(season=season_).obj_medians(attr='size')##obj_means("size")
    sns.histplot(dat,label=season_.name,alpha=1-(i*0.23),color=colors[i],bins=50, binrange=(0,250000), stat='density')

 
ax.set_xlabel('Median Object size [km²]')
ax.set_ylabel('probability density')
plt.legend()
plt.grid()
ax.set_xlim(0,250000)
# Out:
# (0.0, 250000.0)

# %% [markdown]
# # Median Total IVT content of IVT-objects

# %% [markdown]
# # Median speed of objects

# %%
fig, ax = plt.subplots()

for i,season_ in enumerate(Season):


    dat=IVTobj_ls.sel_season(season=season_).obj_medians(attr='speed')##obj_means("size")
    
    sns.histplot(dat,label=season_.name,alpha=1-(i*0.23),color=colors[i],bins=50, binrange=(0,70), stat='density')

ax.set_xlabel('Median speed [m/s]')
ax.set_ylabel('probability density')
plt.legend()
plt.grid()
ax.set_xlim(0,70)
# Out:
# /work/aa0238/a271093/Scripts/MOAAP/src/xarray_util.py:199: RuntimeWarning: All-NaN slice encountered
#   return np.nanmedian(getattr(self._obj.get, attr))
# /work/aa0238/a271093/Scripts/MOAAP/src/xarray_util.py:199: RuntimeWarning: All-NaN slice encountered
#   return np.nanmedian(getattr(self._obj.get, attr))
# /work/aa0238/a271093/Scripts/MOAAP/src/xarray_util.py:199: RuntimeWarning: All-NaN slice encountered
#   return np.nanmedian(getattr(self._obj.get, attr))
# (0.0, 70.0)

# %% [markdown]
# # Divide IVT object into different classes:
# - Small objects: Median total IVT smaller than the 0.33 quantile
# - Medium objects: Median total IVT larger than the 0.33 quantile and smaller than 0.66 quantile
# - Large objects: Median total IVT larger than the 0.66 quantile

# %%
q033 = IVTobj_ls.quantile(attr='total_IVT', quant = 0.33)
q066 = IVTobj_ls.quantile(attr='total_IVT', quant = 0.66)

# %%
small_objs =  IVTobj_ls.filter_by_median(threshold = q033, attr = 'size', above=False)
medium_objs =  IVTobj_ls.filter_by_median(threshold = q033, attr = 'size', above=True).filter_by_median(threshold = q066, attr = 'total_IVT', above=False)
large_objs =  IVTobj_ls.filter_by_median(threshold = q066, attr = 'size', above=True)

objs = [small_objs, medium_objs, large_objs]

# %% [markdown]
# # Median speed of objects

# %%
fig, ax = plt.subplots()
range_=(0,70)
for i in range(len(objs)):


    #dat=objs[i].sel_season(season=Season.WINTER).obj_medians(attr='speed')##obj_means("size")
    dat=objs[i].obj_medians(attr='speed')##obj_means("size")

    sns.histplot(dat,label=labels[i],alpha=1-(i*0.2),color=colors[i],bins=50, binrange=range_, stat='density')

ax.set_xlabel('Median speed [m/s]')
ax.set_ylabel('probability density')
plt.legend()
plt.grid()
ax.set_xlim(range_)
# Out:
# /work/aa0238/a271093/Scripts/MOAAP/src/xarray_util.py:199: RuntimeWarning: All-NaN slice encountered
#   return np.nanmedian(getattr(self._obj.get, attr))
# (0.0, 70.0)

# %% [markdown]
# # Duration of objects

# %%
fig, ax = plt.subplots()
range_=(12,180)

for i in range(len(objs)):


    dat=objs[i].obj_medians(attr='duration')##obj_means("size")
    
    sns.histplot(dat,label=labels[i],alpha=1-(i*0.2),color=colors[i],bins=58, binrange=range_, stat='density')

ax.set_xlabel('Duration [hrs]')
ax.set_ylabel('probability density')
plt.legend()
plt.grid()
ax.set_xlim(range_)
# Out:
# (12.0, 180.0)

# %%
d=(IVTobj_ls[0].times.values[1]- IVTobj_ls[0].times.values[0]).astype('timedelta64[h]').astype('int')

# %%
(d/(1000*1000*1000*60*24))
# Out:
# numpy.timedelta64(15,'ns')

# %%
d/777
# Out:
# numpy.timedelta64(27799227799,'ns')

# %%
IVTobj_ls[0].times.values[1]
# Out:
# numpy.datetime64('1979-01-01T12:00:00.000000000')

# %%
IVTobj_ls[0].times.values[0]
# Out:
# numpy.datetime64('1979-01-01T06:00:00.000000000')

# %%
d.astype('timedelta64[h]')
# Out:
# numpy.timedelta64(6,'h')

# %%
IVTobj_ls[0].get.tstep
# Out:
# /work/aa0238/a271093/Scripts/MOAAP/src/xarray_util.py:177: AccessorRegistrationWarning: registration of accessor <class 'src.xarray_util.Accessor'> under name 'get' for type <class 'xarray.core.dataset.Dataset'> is overriding a preexisting attribute with the same name.
#   @xr.register_dataset_accessor("get")
# 6

# %%
d.real
# Out:
# numpy.timedelta64(6,'h')

# %%
IVTobj_ls[0].get.duration
# Out:
# /work/aa0238/a271093/Scripts/MOAAP/src/xarray_util.py:177: AccessorRegistrationWarning: registration of accessor <class 'src.xarray_util.Accessor'> under name 'get' for type <class 'xarray.core.dataset.Dataset'> is overriding a preexisting attribute with the same name.
#   @xr.register_dataset_accessor("get")
# 6
