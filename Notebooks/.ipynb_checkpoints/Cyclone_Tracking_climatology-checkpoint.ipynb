# %% [markdown]
# # Climatological tracking of IVT and AR objects using the MOAAP tracking algorithm
# - Load IVT tracking data in chunks of 7 months with 1 month overlap between chunks
# - Track individual data chunks and correct the pickle and netCdf4 files afterwards, so that each final corrected file corresponds to 6 month, from 1.1-1.7 and 1.7-1-1 respectively
# - Tracking should be done on a rotated grid to avoid strange behaviour around the pole when e.g. using a regular grid
# - Tracking data are remapped to 33km resolution

# %%
# %load_ext autoreload
# %autoreload 2
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import datetime
import cartopy
import cartopy.crs as ccrs
import pickle
#import Tracking_Functions
from dateutil import relativedelta
import os

import src.Tracking_Functions as Tracking_Functions
from src.TrackingDataLoader import * 
from src.utils import * 
from src.Corrections import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Settings

# %%
#data_path = '/work/aa0049/a271109/spice-v2.1/chain/work/polarres_wp3_cmip_CNRM/post/yearly/'


suffix = 'remapped_3x'
file_type = '.nc'
threshold_path = '/work/aa0238/a271093/data/input/'




#######ICON########

#first_year = 1984
#last_year = 2014

#data_path = '/work/aa0238/a271093/data/Jan_runs/CNRM_control_remapped_3x/'
#output_path = '/work/aa0238/a271093/results/MOAAP/IVT_Tracking/CNRM_control_remapped_3x/'
#output_file_name_temp = f'MOAPP_ICON_100and85controlperc_{suffix}'

#output_path = '/work/aa0238/a271093/scratch/Track_test/'




#####ERA5######

first_year = 1979
last_year = 1980


data_path = '/work/aa0238/a271093/data/ERA5/1979-2023/ICON_remapped_3x/'
output_path = '/work/aa0238/a271093/results/MOAAP/Cyclone_Tracking/ERA5_ICON_remapped_3x/'
output_file_name_temp = f'MOAPP_ERA5_{suffix}'
#threshold_file = threshold_path+'ivt_percentile_mlauer_removed-ens-lev_remapbilWP3domain_3dx3dy.nc'

#ds_ivt_pctl=xr.open_dataset(threshold_file,decode_times=False)
#IVTtrheshold=ds_ivt_pctl.ivt1.values

# %%
start_date_list, end_date_list = create_datetime_lists(first_year,last_year) 
first_processed_date = start_date_list[0]
last_processed_date = end_date_list[-1]

# %%
 Psl_Loader= TrackingDataLoader('psl', data_path, suffix=suffix, file_type = file_type)

dict_keys_offset = 0

for start_date, end_date in zip(start_date_list, end_date_list):
    
    print ("\n \n \n \n")
    
    Psl_Loader.start_date = start_date    
    Psl_Loader.end_date = end_date

    print ( Psl_Loader.start_date, Psl_Loader.end_date)
    

    Psl_data=Psl_Loader.load_datasets(rm_nc=False)

    rLon = xr.broadcast(Psl_data.rlon, Psl_data.rlat)[0].values.T
    rLat = xr.broadcast(Psl_data.rlon, Psl_data.rlat)[1].values.T

    Lon = xr.broadcast(Psl_data.lon, Psl_data.lat)[0].values
    Lat = xr.broadcast(Psl_data.lon, Psl_data.lat)[1].values

    Mask=1*(rLat>-999)
    Time_sel = Psl_Loader.time_sel
    
    output_file_name = f'{output_file_name_temp}_{get_datetime_str(start_date)}-{get_datetime_str(end_date)}'

    

    Tracking_Functions.moaap(Lon = rLon,                            # 2Dlongitude grid centers
                              Lat = rLat,                           # 2D latitude grid spacing
                              Time = Time_sel,                      # datetime vector of data
                              dT = 6,                               # integer - temporal frequency of data [hour]
                              Mask = Mask,                          # mask with dimensions [lat,lon] defining analysis region

                              slp = Psl_data.psl.values,          
                              regular_Lon = Lon,
                              regular_Lat = Lat,                                                                    # JLa: additionall fixed threshold 100 in code

                              DataName = output_file_name,
                              OutputFolder=output_path ,
                              dict_keys_offset = dict_keys_offset
                            )
                       
                             
    cleanup_dicts(output_path,
                  output_file_name_temp,
                  start_date,
                  end_date, 
                  last_processed_date,
                  type_='CY'
                 )
    
    cleanup_dicts(output_path,
                  output_file_name_temp,
                  start_date,
                  end_date, 
                  last_processed_date,
                  type_='ACY'
                 )
        

    
    correct_nc_file(output_path,
                    output_file_name_temp, 
                    start_date,
                    end_date,
                    last_processed_date
                   )
                             
    dict_keys_offset +=5000
# Out:
#
#
#
#
# 1979-01-01 00:00:00 1979-08-01 00:00:00
#
# The provided variables allow tracking the following phenomena
#
# |  phenomenon  | tracking |
# ---------------------------
#    Jetstream   |   no
#    PSL CY/ACY  |   yes
#    Z500 CY/ACY |   no
#    COLs        |   no
#    IVT ARs     |   no
#    MS ARs      |   no
#    Fronts      |   no
#    TCs         |   no
#    MCSs        |   no
#    Equ. Waves  |   no
# ---------------------------
#
# ======> track cyclones from PSL
#         track cyclones
#             551 object found
#             break up long living CY objects that heve many elements
# 100%|██████████| 551/551 [00:03<00:00, 172.52it/s]
#         00:00:04.44
#         track anti-cyclones
#         494 object found
#             break up long living ACY objects that have many elements
# 100%|██████████| 494/494 [00:02<00:00, 165.90it/s]
#         00:00:05.46
#             Loop over 1400 objects
#             Loop over 1708 objects
#         00:00:16.48
#
# Save the object masks into a joint netCDF
# Saved: /work/aa0238/a271093/results/MOAAP/Cyclone_Tracking/ERA5_ICON_remapped_3x/ObjectMasks_MOAPP_ERA5_100and85controlperc_remapped_3x_1979_01_01-1979_08_01.nc
#         00:00:03.77
# clean up /work/aa0238/a271093/results/MOAAP/Cyclone_Tracking/ERA5_ICON_remapped_3x/CY_MOAPP_ERA5_100and85controlperc_remapped_3x_1979_01_01-1979_07_01.pkl
# clean up finished
# clean up /work/aa0238/a271093/results/MOAAP/Cyclone_Tracking/ERA5_ICON_remapped_3x/ACY_MOAPP_ERA5_100and85controlperc_remapped_3x_1979_01_01-1979_07_01.pkl
# clean up finished
# correct nc-file with
#  cdo -selmon,1,2,3,4,5,6 /work/aa0238/a271093/results/MOAAP/Cyclone_Tracking/ERA5_ICON_remapped_3x/ObjectMasks_MOAPP_ERA5_100and85controlperc_remapped_3x_1979_01_01-1979_08_01.nc /work/aa0238/a271093/results/MOAAP/Cyclone_Tracking/ERA5_ICON_remapped_3x/ObjectMasks_MOAPP_ERA5_100and85controlperc_remapped_3x_1979_01_01-1979_07_01_corrected.nc
#
#
#
#
#
# 1979-07-01 00:00:00 1980-01-01 00:00:00
# Mergetime /work/aa0238/a271093/data/ERA5/1979-2023/ICON_remapped_3x/psl/psl_1979010100-1979123123_remapped_3x.nc /work/aa0238/a271093/data/ERA5/1979-2023/ICON_remapped_3x/psl/psl_1980010100-1980123123_remapped_3x.nc  /work/aa0238/a271093/scratch/mergedpsl_1979_1980_remapped_3x.nc
#
# The provided variables allow tracking the following phenomena
#
# |  phenomenon  | tracking |
# ---------------------------
#    Jetstream   |   no
#    PSL CY/ACY  |   yes
#    Z500 CY/ACY |   no
#    COLs        |   no
#    IVT ARs     |   no
#    MS ARs      |   no
#    Fronts      |   no
#    TCs         |   no
#    MCSs        |   no
#    Equ. Waves  |   no
# ---------------------------
#
# ======> track cyclones from PSL
#         track cyclones
#             442 object found
#             break up long living CY objects that heve many elements
# 100%|██████████| 442/442 [00:02<00:00, 176.63it/s]
#         00:00:03.29
#         track anti-cyclones
#         376 object found
#             break up long living ACY objects that have many elements
# 100%|██████████| 376/376 [00:03<00:00, 117.25it/s]
#         00:00:04.82
#             Loop over 1028 objects
# /work/aa0238/a271093/Scripts/MOAAP/src/Tracking_Functions.py:256: RuntimeWarning: All-NaN slice encountered
#   # ### JLa
# /work/aa0238/a271093/Scripts/MOAAP/src/Tracking_Functions.py:257: RuntimeWarning: All-NaN slice encountered
#   obj_mass_center = \
# /work/aa0238/a271093/Scripts/MOAAP/src/Tracking_Functions.py:258: RuntimeWarning: Mean of empty slice
#   np.array([ndimage.center_of_mass(object_slice[tt,:,:]==(iobj+1)) for tt in range(object_slice.shape[0])])
# /work/aa0238/a271093/Conda/MOAAP_env/lib/python3.12/site-packages/scipy/ndimage/_measurements.py:1541: RuntimeWarning: invalid value encountered in scalar divide
#   results = [sum(input * grids[dir].astype(float), labels, index) / normalizer
#             Loop over 1664 objects
#         00:00:15.81
#
# Save the object masks into a joint netCDF
# Saved: /work/aa0238/a271093/results/MOAAP/Cyclone_Tracking/ERA5_ICON_remapped_3x/ObjectMasks_MOAPP_ERA5_100and85controlperc_remapped_3x_1979_07_01-1980_01_01.nc
#         00:00:04.27
# clean up /work/aa0238/a271093/results/MOAAP/Cyclone_Tracking/ERA5_ICON_remapped_3x/CY_MOAPP_ERA5_100and85controlperc_remapped_3x_1979_07_01-1980_01_01.pkl
# clean up finished
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[31], line 46
#      26 output_file_name = f'{output_file_name_temp}_{get_datetime_str(start_date)}-{get_datetime_str(end_date)}'
#      30 Tracking_Functions.moaap(Lon = rLon,                            # 2Dlongitude grid centers
#      31                           Lat = rLat,                           # 2D latitude grid spacing
#      32                           Time = Time_sel,                      # datetime vector of data
#    (...)
#      42                           dict_keys_offset = dict_keys_offset
#      43                         )
# ---> 46 cleanup_dicts(output_path,
#      47               output_file_name_temp,
#      48               start_date,
#      49               end_date,
#      50               last_processed_date,
#      51               type_='CY'
#      52              )
#      54 cleanup_dicts(output_path,
#      55               output_file_name_temp,
#      56               start_date,
#    (...)
#      59               type_='ACY'
#      60              )
#      64 correct_nc_file(output_path,
#      65                 output_file_name_temp,
#      66                 start_date,
#      67                 end_date,
#      68                 last_processed_date
#      69                )
#
# File /work/aa0238/a271093/Scripts/MOAAP/src/Corrections.py:90, in cleanup_dicts(output_path, output_file_name_temp, file_start_date, file_end_date, last_processed_date, type_)
#      87     output_name = f"{output_path}{type_}_{output_file_name_temp}_{get_datetime_str(file_start_date)}-{get_datetime_str(file_end_date)}"
#      89 print("clean up finished")
# ---> 90 save_as_pkl(obj_dict, output_name=output_name + "_corrected")
#      92 # print("remove old pickle file")
#      94 os.remove(f"{input_name}.pkl")
#
# UnboundLocalError: cannot access local variable 'output_name' where it is not associated with a value

# %%
#with open('/work/aa0238/a271093/results/MOAAP/IVT_Tracking/CNRM_control_test/IVT_MOAPP_ICON_control_CNRMforc_100and85controlperc_remapped_3x_1984_01_01-1984_07_01_corrected.pkl', 'rb') as pickle_file:
#    IVT1 = pickle.load(pickle_file)

# %%
Time_sel
# Out:
# array([datetime.datetime(1979, 1, 1, 6, 0),
#        datetime.datetime(1979, 1, 1, 12, 0),
#        datetime.datetime(1979, 1, 1, 18, 0),
#        datetime.datetime(1979, 1, 2, 0, 0),
#        datetime.datetime(1979, 1, 2, 6, 0),
#        datetime.datetime(1979, 1, 2, 12, 0),
#        datetime.datetime(1979, 1, 2, 18, 0),
#        datetime.datetime(1979, 1, 3, 0, 0),
#        datetime.datetime(1979, 1, 3, 6, 0),
#        datetime.datetime(1979, 1, 3, 12, 0),
#        datetime.datetime(1979, 1, 3, 18, 0),
#        datetime.datetime(1979, 1, 4, 0, 0),
#        datetime.datetime(1979, 1, 4, 6, 0),
#        datetime.datetime(1979, 1, 4, 12, 0),
#        datetime.datetime(1979, 1, 4, 18, 0),
#        datetime.datetime(1979, 1, 5, 0, 0),
#        datetime.datetime(1979, 1, 5, 6, 0),
#        datetime.datetime(1979, 1, 5, 12, 0),
#        datetime.datetime(1979, 1, 5, 18, 0),
#        datetime.datetime(1979, 1, 6, 0, 0),
#        datetime.datetime(1979, 1, 6, 6, 0),
#        datetime.datetime(1979, 1, 6, 12, 0),
#        datetime.datetime(1979, 1, 6, 18, 0),
#        datetime.datetime(1979, 1, 7, 0, 0),
#        datetime.datetime(1979, 1, 7, 6, 0),
#        datetime.datetime(1979, 1, 7, 12, 0),
#        datetime.datetime(1979, 1, 7, 18, 0),
#        datetime.datetime(1979, 1, 8, 0, 0),
#        datetime.datetime(1979, 1, 8, 6, 0),
#        datetime.datetime(1979, 1, 8, 12, 0),
#        datetime.datetime(1979, 1, 8, 18, 0),
#        datetime.datetime(1979, 1, 9, 0, 0),
#        datetime.datetime(1979, 1, 9, 6, 0),
#        datetime.datetime(1979, 1, 9, 12, 0),
#        datetime.datetime(1979, 1, 9, 18, 0),
#        datetime.datetime(1979, 1, 10, 0, 0),
#        datetime.datetime(1979, 1, 10, 6, 0),
#        datetime.datetime(1979, 1, 10, 12, 0),
#        datetime.datetime(1979, 1, 10, 18, 0),
#        datetime.datetime(1979, 1, 11, 0, 0),
#        datetime.datetime(1979, 1, 11, 6, 0),
#        datetime.datetime(1979, 1, 11, 12, 0),
#        datetime.datetime(1979, 1, 11, 18, 0),
#        datetime.datetime(1979, 1, 12, 0, 0),
#        datetime.datetime(1979, 1, 12, 6, 0),
#        datetime.datetime(1979, 1, 12, 12, 0),
#        datetime.datetime(1979, 1, 12, 18, 0),
#        datetime.datetime(1979, 1, 13, 0, 0),
#        datetime.datetime(1979, 1, 13, 6, 0),
#        datetime.datetime(1979, 1, 13, 12, 0),
#        datetime.datetime(1979, 1, 13, 18, 0),
#        datetime.datetime(1979, 1, 14, 0, 0),
#        datetime.datetime(1979, 1, 14, 6, 0),
#        datetime.datetime(1979, 1, 14, 12, 0),
#        datetime.datetime(1979, 1, 14, 18, 0),
#        datetime.datetime(1979, 1, 15, 0, 0),
#        datetime.datetime(1979, 1, 15, 6, 0),
#        datetime.datetime(1979, 1, 15, 12, 0),
#        datetime.datetime(1979, 1, 15, 18, 0),
#        datetime.datetime(1979, 1, 16, 0, 0),
#        datetime.datetime(1979, 1, 16, 6, 0),
#        datetime.datetime(1979, 1, 16, 12, 0),
#        datetime.datetime(1979, 1, 16, 18, 0),
#        datetime.datetime(1979, 1, 17, 0, 0),
#        datetime.datetime(1979, 1, 17, 6, 0),
#        datetime.datetime(1979, 1, 17, 12, 0),
#        datetime.datetime(1979, 1, 17, 18, 0),
#        datetime.datetime(1979, 1, 18, 0, 0),
#        datetime.datetime(1979, 1, 18, 6, 0),
#        datetime.datetime(1979, 1, 18, 12, 0),
#        datetime.datetime(1979, 1, 18, 18, 0),
#        datetime.datetime(1979, 1, 19, 0, 0),
#        datetime.datetime(1979, 1, 19, 6, 0),
#        datetime.datetime(1979, 1, 19, 12, 0),
#        datetime.datetime(1979, 1, 19, 18, 0),
#        datetime.datetime(1979, 1, 20, 0, 0),
#        datetime.datetime(1979, 1, 20, 6, 0),
#        datetime.datetime(1979, 1, 20, 12, 0),
#        datetime.datetime(1979, 1, 20, 18, 0),
#        datetime.datetime(1979, 1, 21, 0, 0),
#        datetime.datetime(1979, 1, 21, 6, 0),
#        datetime.datetime(1979, 1, 21, 12, 0),
#        datetime.datetime(1979, 1, 21, 18, 0),
#        datetime.datetime(1979, 1, 22, 0, 0),
#        datetime.datetime(1979, 1, 22, 6, 0),
#        datetime.datetime(1979, 1, 22, 12, 0),
#        datetime.datetime(1979, 1, 22, 18, 0),
#        datetime.datetime(1979, 1, 23, 0, 0),
#        datetime.datetime(1979, 1, 23, 6, 0),
#        datetime.datetime(1979, 1, 23, 12, 0),
#        datetime.datetime(1979, 1, 23, 18, 0),
#        datetime.datetime(1979, 1, 24, 0, 0),
#        datetime.datetime(1979, 1, 24, 6, 0),
#        datetime.datetime(1979, 1, 24, 12, 0),
#        datetime.datetime(1979, 1, 24, 18, 0),
#        datetime.datetime(1979, 1, 25, 0, 0),
#        datetime.datetime(1979, 1, 25, 6, 0),
#        datetime.datetime(1979, 1, 25, 12, 0),
#        datetime.datetime(1979, 1, 25, 18, 0),
#        datetime.datetime(1979, 1, 26, 0, 0),
#        datetime.datetime(1979, 1, 26, 6, 0),
#        datetime.datetime(1979, 1, 26, 12, 0),
#        datetime.datetime(1979, 1, 26, 18, 0),
#        datetime.datetime(1979, 1, 27, 0, 0),
#        datetime.datetime(1979, 1, 27, 6, 0),
#        datetime.datetime(1979, 1, 27, 12, 0),
#        datetime.datetime(1979, 1, 27, 18, 0),
#        datetime.datetime(1979, 1, 28, 0, 0),
#        datetime.datetime(1979, 1, 28, 6, 0),
#        datetime.datetime(1979, 1, 28, 12, 0),
#        datetime.datetime(1979, 1, 28, 18, 0),
#        datetime.datetime(1979, 1, 29, 0, 0),
#        datetime.datetime(1979, 1, 29, 6, 0),
#        datetime.datetime(1979, 1, 29, 12, 0),
#        datetime.datetime(1979, 1, 29, 18, 0),
#        datetime.datetime(1979, 1, 30, 0, 0),
#        datetime.datetime(1979, 1, 30, 6, 0),
#        datetime.datetime(1979, 1, 30, 12, 0),
#        datetime.datetime(1979, 1, 30, 18, 0),
#        datetime.datetime(1979, 1, 31, 0, 0),
#        datetime.datetime(1979, 1, 31, 6, 0),
#        datetime.datetime(1979, 1, 31, 12, 0),
#        datetime.datetime(1979, 1, 31, 18, 0),
#        datetime.datetime(1979, 2, 1, 0, 0),
#        datetime.datetime(1979, 2, 1, 6, 0),
#        datetime.datetime(1979, 2, 1, 12, 0),
#        datetime.datetime(1979, 2, 1, 18, 0),
#        datetime.datetime(1979, 2, 2, 0, 0),
#        datetime.datetime(1979, 2, 2, 6, 0),
#        datetime.datetime(1979, 2, 2, 12, 0),
#        datetime.datetime(1979, 2, 2, 18, 0),
#        datetime.datetime(1979, 2, 3, 0, 0),
#        datetime.datetime(1979, 2, 3, 6, 0),
#        datetime.datetime(1979, 2, 3, 12, 0),
#        datetime.datetime(1979, 2, 3, 18, 0),
#        datetime.datetime(1979, 2, 4, 0, 0),
#        datetime.datetime(1979, 2, 4, 6, 0),
#        datetime.datetime(1979, 2, 4, 12, 0),
#        datetime.datetime(1979, 2, 4, 18, 0),
#        datetime.datetime(1979, 2, 5, 0, 0),
#        datetime.datetime(1979, 2, 5, 6, 0),
#        datetime.datetime(1979, 2, 5, 12, 0),
#        datetime.datetime(1979, 2, 5, 18, 0),
#        datetime.datetime(1979, 2, 6, 0, 0),
#        datetime.datetime(1979, 2, 6, 6, 0),
#        datetime.datetime(1979, 2, 6, 12, 0),
#        datetime.datetime(1979, 2, 6, 18, 0),
#        datetime.datetime(1979, 2, 7, 0, 0),
#        datetime.datetime(1979, 2, 7, 6, 0),
#        datetime.datetime(1979, 2, 7, 12, 0),
#        datetime.datetime(1979, 2, 7, 18, 0),
#        datetime.datetime(1979, 2, 8, 0, 0),
#        datetime.datetime(1979, 2, 8, 6, 0),
#        datetime.datetime(1979, 2, 8, 12, 0),
#        datetime.datetime(1979, 2, 8, 18, 0),
#        datetime.datetime(1979, 2, 9, 0, 0),
#        datetime.datetime(1979, 2, 9, 6, 0),
#        datetime.datetime(1979, 2, 9, 12, 0),
#        datetime.datetime(1979, 2, 9, 18, 0),
#        datetime.datetime(1979, 2, 10, 0, 0),
#        datetime.datetime(1979, 2, 10, 6, 0),
#        datetime.datetime(1979, 2, 10, 12, 0),
#        datetime.datetime(1979, 2, 10, 18, 0),
#        datetime.datetime(1979, 2, 11, 0, 0),
#        datetime.datetime(1979, 2, 11, 6, 0),
#        datetime.datetime(1979, 2, 11, 12, 0),
#        datetime.datetime(1979, 2, 11, 18, 0),
#        datetime.datetime(1979, 2, 12, 0, 0),
#        datetime.datetime(1979, 2, 12, 6, 0),
#        datetime.datetime(1979, 2, 12, 12, 0),
#        datetime.datetime(1979, 2, 12, 18, 0),
#        datetime.datetime(1979, 2, 13, 0, 0),
#        datetime.datetime(1979, 2, 13, 6, 0),
#        datetime.datetime(1979, 2, 13, 12, 0),
#        datetime.datetime(1979, 2, 13, 18, 0),
#        datetime.datetime(1979, 2, 14, 0, 0),
#        datetime.datetime(1979, 2, 14, 6, 0),
#        datetime.datetime(1979, 2, 14, 12, 0),
#        datetime.datetime(1979, 2, 14, 18, 0),
#        datetime.datetime(1979, 2, 15, 0, 0),
#        datetime.datetime(1979, 2, 15, 6, 0),
#        datetime.datetime(1979, 2, 15, 12, 0),
#        datetime.datetime(1979, 2, 15, 18, 0),
#        datetime.datetime(1979, 2, 16, 0, 0),
#        datetime.datetime(1979, 2, 16, 6, 0),
#        datetime.datetime(1979, 2, 16, 12, 0),
#        datetime.datetime(1979, 2, 16, 18, 0),
#        datetime.datetime(1979, 2, 17, 0, 0),
#        datetime.datetime(1979, 2, 17, 6, 0),
#        datetime.datetime(1979, 2, 17, 12, 0),
#        datetime.datetime(1979, 2, 17, 18, 0),
#        datetime.datetime(1979, 2, 18, 0, 0),
#        datetime.datetime(1979, 2, 18, 6, 0),
#        datetime.datetime(1979, 2, 18, 12, 0),
#        datetime.datetime(1979, 2, 18, 18, 0),
#        datetime.datetime(1979, 2, 19, 0, 0),
#        datetime.datetime(1979, 2, 19, 6, 0),
#        datetime.datetime(1979, 2, 19, 12, 0),
#        datetime.datetime(1979, 2, 19, 18, 0),
#        datetime.datetime(1979, 2, 20, 0, 0),
#        datetime.datetime(1979, 2, 20, 6, 0),
#        datetime.datetime(1979, 2, 20, 12, 0),
#        datetime.datetime(1979, 2, 20, 18, 0),
#        datetime.datetime(1979, 2, 21, 0, 0),
#        datetime.datetime(1979, 2, 21, 6, 0),
#        datetime.datetime(1979, 2, 21, 12, 0),
#        datetime.datetime(1979, 2, 21, 18, 0),
#        datetime.datetime(1979, 2, 22, 0, 0),
#        datetime.datetime(1979, 2, 22, 6, 0),
#        datetime.datetime(1979, 2, 22, 12, 0),
#        datetime.datetime(1979, 2, 22, 18, 0),
#        datetime.datetime(1979, 2, 23, 0, 0),
#        datetime.datetime(1979, 2, 23, 6, 0),
#        datetime.datetime(1979, 2, 23, 12, 0),
#        datetime.datetime(1979, 2, 23, 18, 0),
#        datetime.datetime(1979, 2, 24, 0, 0),
#        datetime.datetime(1979, 2, 24, 6, 0),
#        datetime.datetime(1979, 2, 24, 12, 0),
#        datetime.datetime(1979, 2, 24, 18, 0),
#        datetime.datetime(1979, 2, 25, 0, 0),
#        datetime.datetime(1979, 2, 25, 6, 0),
#        datetime.datetime(1979, 2, 25, 12, 0),
#        datetime.datetime(1979, 2, 25, 18, 0),
#        datetime.datetime(1979, 2, 26, 0, 0),
#        datetime.datetime(1979, 2, 26, 6, 0),
#        datetime.datetime(1979, 2, 26, 12, 0),
#        datetime.datetime(1979, 2, 26, 18, 0),
#        datetime.datetime(1979, 2, 27, 0, 0),
#        datetime.datetime(1979, 2, 27, 6, 0),
#        datetime.datetime(1979, 2, 27, 12, 0),
#        datetime.datetime(1979, 2, 27, 18, 0),
#        datetime.datetime(1979, 2, 28, 0, 0),
#        datetime.datetime(1979, 2, 28, 6, 0),
#        datetime.datetime(1979, 2, 28, 12, 0),
#        datetime.datetime(1979, 2, 28, 18, 0),
#        datetime.datetime(1979, 3, 1, 0, 0),
#        datetime.datetime(1979, 3, 1, 6, 0),
#        datetime.datetime(1979, 3, 1, 12, 0),
#        datetime.datetime(1979, 3, 1, 18, 0),
#        datetime.datetime(1979, 3, 2, 0, 0),
#        datetime.datetime(1979, 3, 2, 6, 0),
#        datetime.datetime(1979, 3, 2, 12, 0),
#        datetime.datetime(1979, 3, 2, 18, 0),
#        datetime.datetime(1979, 3, 3, 0, 0),
#        datetime.datetime(1979, 3, 3, 6, 0),
#        datetime.datetime(1979, 3, 3, 12, 0),
#        datetime.datetime(1979, 3, 3, 18, 0),
#        datetime.datetime(1979, 3, 4, 0, 0),
#        datetime.datetime(1979, 3, 4, 6, 0),
#        datetime.datetime(1979, 3, 4, 12, 0),
#        datetime.datetime(1979, 3, 4, 18, 0),
#        datetime.datetime(1979, 3, 5, 0, 0),
#        datetime.datetime(1979, 3, 5, 6, 0),
#        datetime.datetime(1979, 3, 5, 12, 0),
#        datetime.datetime(1979, 3, 5, 18, 0),
#        datetime.datetime(1979, 3, 6, 0, 0),
#        datetime.datetime(1979, 3, 6, 6, 0),
#        datetime.datetime(1979, 3, 6, 12, 0),
#        datetime.datetime(1979, 3, 6, 18, 0),
#        datetime.datetime(1979, 3, 7, 0, 0),
#        datetime.datetime(1979, 3, 7, 6, 0),
#        datetime.datetime(1979, 3, 7, 12, 0),
#        datetime.datetime(1979, 3, 7, 18, 0),
#        datetime.datetime(1979, 3, 8, 0, 0),
#        datetime.datetime(1979, 3, 8, 6, 0),
#        datetime.datetime(1979, 3, 8, 12, 0),
#        datetime.datetime(1979, 3, 8, 18, 0),
#        datetime.datetime(1979, 3, 9, 0, 0),
#        datetime.datetime(1979, 3, 9, 6, 0),
#        datetime.datetime(1979, 3, 9, 12, 0),
#        datetime.datetime(1979, 3, 9, 18, 0),
#        datetime.datetime(1979, 3, 10, 0, 0),
#        datetime.datetime(1979, 3, 10, 6, 0),
#        datetime.datetime(1979, 3, 10, 12, 0),
#        datetime.datetime(1979, 3, 10, 18, 0),
#        datetime.datetime(1979, 3, 11, 0, 0),
#        datetime.datetime(1979, 3, 11, 6, 0),
#        datetime.datetime(1979, 3, 11, 12, 0),
#        datetime.datetime(1979, 3, 11, 18, 0),
#        datetime.datetime(1979, 3, 12, 0, 0),
#        datetime.datetime(1979, 3, 12, 6, 0),
#        datetime.datetime(1979, 3, 12, 12, 0),
#        datetime.datetime(1979, 3, 12, 18, 0),
#        datetime.datetime(1979, 3, 13, 0, 0),
#        datetime.datetime(1979, 3, 13, 6, 0),
#        datetime.datetime(1979, 3, 13, 12, 0),
#        datetime.datetime(1979, 3, 13, 18, 0),
#        datetime.datetime(1979, 3, 14, 0, 0),
#        datetime.datetime(1979, 3, 14, 6, 0),
#        datetime.datetime(1979, 3, 14, 12, 0),
#        datetime.datetime(1979, 3, 14, 18, 0),
#        datetime.datetime(1979, 3, 15, 0, 0),
#        datetime.datetime(1979, 3, 15, 6, 0),
#        datetime.datetime(1979, 3, 15, 12, 0),
#        datetime.datetime(1979, 3, 15, 18, 0),
#        datetime.datetime(1979, 3, 16, 0, 0),
#        datetime.datetime(1979, 3, 16, 6, 0),
#        datetime.datetime(1979, 3, 16, 12, 0),
#        datetime.datetime(1979, 3, 16, 18, 0),
#        datetime.datetime(1979, 3, 17, 0, 0),
#        datetime.datetime(1979, 3, 17, 6, 0),
#        datetime.datetime(1979, 3, 17, 12, 0),
#        datetime.datetime(1979, 3, 17, 18, 0),
#        datetime.datetime(1979, 3, 18, 0, 0),
#        datetime.datetime(1979, 3, 18, 6, 0),
#        datetime.datetime(1979, 3, 18, 12, 0),
#        datetime.datetime(1979, 3, 18, 18, 0),
#        datetime.datetime(1979, 3, 19, 0, 0),
#        datetime.datetime(1979, 3, 19, 6, 0),
#        datetime.datetime(1979, 3, 19, 12, 0),
#        datetime.datetime(1979, 3, 19, 18, 0),
#        datetime.datetime(1979, 3, 20, 0, 0),
#        datetime.datetime(1979, 3, 20, 6, 0),
#        datetime.datetime(1979, 3, 20, 12, 0),
#        datetime.datetime(1979, 3, 20, 18, 0),
#        datetime.datetime(1979, 3, 21, 0, 0),
#        datetime.datetime(1979, 3, 21, 6, 0),
#        datetime.datetime(1979, 3, 21, 12, 0),
#        datetime.datetime(1979, 3, 21, 18, 0),
#        datetime.datetime(1979, 3, 22, 0, 0),
#        datetime.datetime(1979, 3, 22, 6, 0),
#        datetime.datetime(1979, 3, 22, 12, 0),
#        datetime.datetime(1979, 3, 22, 18, 0),
#        datetime.datetime(1979, 3, 23, 0, 0),
#        datetime.datetime(1979, 3, 23, 6, 0),
#        datetime.datetime(1979, 3, 23, 12, 0),
#        datetime.datetime(1979, 3, 23, 18, 0),
#        datetime.datetime(1979, 3, 24, 0, 0),
#        datetime.datetime(1979, 3, 24, 6, 0),
#        datetime.datetime(1979, 3, 24, 12, 0),
#        datetime.datetime(1979, 3, 24, 18, 0),
#        datetime.datetime(1979, 3, 25, 0, 0),
#        datetime.datetime(1979, 3, 25, 6, 0),
#        datetime.datetime(1979, 3, 25, 12, 0),
#        datetime.datetime(1979, 3, 25, 18, 0),
#        datetime.datetime(1979, 3, 26, 0, 0),
#        datetime.datetime(1979, 3, 26, 6, 0),
#        datetime.datetime(1979, 3, 26, 12, 0),
#        datetime.datetime(1979, 3, 26, 18, 0),
#        datetime.datetime(1979, 3, 27, 0, 0),
#        datetime.datetime(1979, 3, 27, 6, 0),
#        datetime.datetime(1979, 3, 27, 12, 0),
#        datetime.datetime(1979, 3, 27, 18, 0),
#        datetime.datetime(1979, 3, 28, 0, 0),
#        datetime.datetime(1979, 3, 28, 6, 0),
#        datetime.datetime(1979, 3, 28, 12, 0),
#        datetime.datetime(1979, 3, 28, 18, 0),
#        datetime.datetime(1979, 3, 29, 0, 0),
#        datetime.datetime(1979, 3, 29, 6, 0),
#        datetime.datetime(1979, 3, 29, 12, 0),
#        datetime.datetime(1979, 3, 29, 18, 0),
#        datetime.datetime(1979, 3, 30, 0, 0),
#        datetime.datetime(1979, 3, 30, 6, 0),
#        datetime.datetime(1979, 3, 30, 12, 0),
#        datetime.datetime(1979, 3, 30, 18, 0),
#        datetime.datetime(1979, 3, 31, 0, 0),
#        datetime.datetime(1979, 3, 31, 6, 0),
#        datetime.datetime(1979, 3, 31, 12, 0),
#        datetime.datetime(1979, 3, 31, 18, 0),
#        datetime.datetime(1979, 4, 1, 0, 0),
#        datetime.datetime(1979, 4, 1, 6, 0),
#        datetime.datetime(1979, 4, 1, 12, 0),
#        datetime.datetime(1979, 4, 1, 18, 0),
#        datetime.datetime(1979, 4, 2, 0, 0),
#        datetime.datetime(1979, 4, 2, 6, 0),
#        datetime.datetime(1979, 4, 2, 12, 0),
#        datetime.datetime(1979, 4, 2, 18, 0),
#        datetime.datetime(1979, 4, 3, 0, 0),
#        datetime.datetime(1979, 4, 3, 6, 0),
#        datetime.datetime(1979, 4, 3, 12, 0),
#        datetime.datetime(1979, 4, 3, 18, 0),
#        datetime.datetime(1979, 4, 4, 0, 0),
#        datetime.datetime(1979, 4, 4, 6, 0),
#        datetime.datetime(1979, 4, 4, 12, 0),
#        datetime.datetime(1979, 4, 4, 18, 0),
#        datetime.datetime(1979, 4, 5, 0, 0),
#        datetime.datetime(1979, 4, 5, 6, 0),
#        datetime.datetime(1979, 4, 5, 12, 0),
#        datetime.datetime(1979, 4, 5, 18, 0),
#        datetime.datetime(1979, 4, 6, 0, 0),
#        datetime.datetime(1979, 4, 6, 6, 0),
#        datetime.datetime(1979, 4, 6, 12, 0),
#        datetime.datetime(1979, 4, 6, 18, 0),
#        datetime.datetime(1979, 4, 7, 0, 0),
#        datetime.datetime(1979, 4, 7, 6, 0),
#        datetime.datetime(1979, 4, 7, 12, 0),
#        datetime.datetime(1979, 4, 7, 18, 0),
#        datetime.datetime(1979, 4, 8, 0, 0),
#        datetime.datetime(1979, 4, 8, 6, 0),
#        datetime.datetime(1979, 4, 8, 12, 0),
#        datetime.datetime(1979, 4, 8, 18, 0),
#        datetime.datetime(1979, 4, 9, 0, 0),
#        datetime.datetime(1979, 4, 9, 6, 0),
#        datetime.datetime(1979, 4, 9, 12, 0),
#        datetime.datetime(1979, 4, 9, 18, 0),
#        datetime.datetime(1979, 4, 10, 0, 0),
#        datetime.datetime(1979, 4, 10, 6, 0),
#        datetime.datetime(1979, 4, 10, 12, 0),
#        datetime.datetime(1979, 4, 10, 18, 0),
#        datetime.datetime(1979, 4, 11, 0, 0),
#        datetime.datetime(1979, 4, 11, 6, 0),
#        datetime.datetime(1979, 4, 11, 12, 0),
#        datetime.datetime(1979, 4, 11, 18, 0),
#        datetime.datetime(1979, 4, 12, 0, 0),
#        datetime.datetime(1979, 4, 12, 6, 0),
#        datetime.datetime(1979, 4, 12, 12, 0),
#        datetime.datetime(1979, 4, 12, 18, 0),
#        datetime.datetime(1979, 4, 13, 0, 0),
#        datetime.datetime(1979, 4, 13, 6, 0),
#        datetime.datetime(1979, 4, 13, 12, 0),
#        datetime.datetime(1979, 4, 13, 18, 0),
#        datetime.datetime(1979, 4, 14, 0, 0),
#        datetime.datetime(1979, 4, 14, 6, 0),
#        datetime.datetime(1979, 4, 14, 12, 0),
#        datetime.datetime(1979, 4, 14, 18, 0),
#        datetime.datetime(1979, 4, 15, 0, 0),
#        datetime.datetime(1979, 4, 15, 6, 0),
#        datetime.datetime(1979, 4, 15, 12, 0),
#        datetime.datetime(1979, 4, 15, 18, 0),
#        datetime.datetime(1979, 4, 16, 0, 0),
#        datetime.datetime(1979, 4, 16, 6, 0),
#        datetime.datetime(1979, 4, 16, 12, 0),
#        datetime.datetime(1979, 4, 16, 18, 0),
#        datetime.datetime(1979, 4, 17, 0, 0),
#        datetime.datetime(1979, 4, 17, 6, 0),
#        datetime.datetime(1979, 4, 17, 12, 0),
#        datetime.datetime(1979, 4, 17, 18, 0),
#        datetime.datetime(1979, 4, 18, 0, 0),
#        datetime.datetime(1979, 4, 18, 6, 0),
#        datetime.datetime(1979, 4, 18, 12, 0),
#        datetime.datetime(1979, 4, 18, 18, 0),
#        datetime.datetime(1979, 4, 19, 0, 0),
#        datetime.datetime(1979, 4, 19, 6, 0),
#        datetime.datetime(1979, 4, 19, 12, 0),
#        datetime.datetime(1979, 4, 19, 18, 0),
#        datetime.datetime(1979, 4, 20, 0, 0),
#        datetime.datetime(1979, 4, 20, 6, 0),
#        datetime.datetime(1979, 4, 20, 12, 0),
#        datetime.datetime(1979, 4, 20, 18, 0),
#        datetime.datetime(1979, 4, 21, 0, 0),
#        datetime.datetime(1979, 4, 21, 6, 0),
#        datetime.datetime(1979, 4, 21, 12, 0),
#        datetime.datetime(1979, 4, 21, 18, 0),
#        datetime.datetime(1979, 4, 22, 0, 0),
#        datetime.datetime(1979, 4, 22, 6, 0),
#        datetime.datetime(1979, 4, 22, 12, 0),
#        datetime.datetime(1979, 4, 22, 18, 0),
#        datetime.datetime(1979, 4, 23, 0, 0),
#        datetime.datetime(1979, 4, 23, 6, 0),
#        datetime.datetime(1979, 4, 23, 12, 0),
#        datetime.datetime(1979, 4, 23, 18, 0),
#        datetime.datetime(1979, 4, 24, 0, 0),
#        datetime.datetime(1979, 4, 24, 6, 0),
#        datetime.datetime(1979, 4, 24, 12, 0),
#        datetime.datetime(1979, 4, 24, 18, 0),
#        datetime.datetime(1979, 4, 25, 0, 0),
#        datetime.datetime(1979, 4, 25, 6, 0),
#        datetime.datetime(1979, 4, 25, 12, 0),
#        datetime.datetime(1979, 4, 25, 18, 0),
#        datetime.datetime(1979, 4, 26, 0, 0),
#        datetime.datetime(1979, 4, 26, 6, 0),
#        datetime.datetime(1979, 4, 26, 12, 0),
#        datetime.datetime(1979, 4, 26, 18, 0),
#        datetime.datetime(1979, 4, 27, 0, 0),
#        datetime.datetime(1979, 4, 27, 6, 0),
#        datetime.datetime(1979, 4, 27, 12, 0),
#        datetime.datetime(1979, 4, 27, 18, 0),
#        datetime.datetime(1979, 4, 28, 0, 0),
#        datetime.datetime(1979, 4, 28, 6, 0),
#        datetime.datetime(1979, 4, 28, 12, 0),
#        datetime.datetime(1979, 4, 28, 18, 0),
#        datetime.datetime(1979, 4, 29, 0, 0),
#        datetime.datetime(1979, 4, 29, 6, 0),
#        datetime.datetime(1979, 4, 29, 12, 0),
#        datetime.datetime(1979, 4, 29, 18, 0),
#        datetime.datetime(1979, 4, 30, 0, 0),
#        datetime.datetime(1979, 4, 30, 6, 0),
#        datetime.datetime(1979, 4, 30, 12, 0),
#        datetime.datetime(1979, 4, 30, 18, 0),
#        datetime.datetime(1979, 5, 1, 0, 0),
#        datetime.datetime(1979, 5, 1, 6, 0),
#        datetime.datetime(1979, 5, 1, 12, 0),
#        datetime.datetime(1979, 5, 1, 18, 0),
#        datetime.datetime(1979, 5, 2, 0, 0),
#        datetime.datetime(1979, 5, 2, 6, 0),
#        datetime.datetime(1979, 5, 2, 12, 0),
#        datetime.datetime(1979, 5, 2, 18, 0),
#        datetime.datetime(1979, 5, 3, 0, 0),
#        datetime.datetime(1979, 5, 3, 6, 0),
#        datetime.datetime(1979, 5, 3, 12, 0),
#        datetime.datetime(1979, 5, 3, 18, 0),
#        datetime.datetime(1979, 5, 4, 0, 0),
#        datetime.datetime(1979, 5, 4, 6, 0),
#        datetime.datetime(1979, 5, 4, 12, 0),
#        datetime.datetime(1979, 5, 4, 18, 0),
#        datetime.datetime(1979, 5, 5, 0, 0),
#        datetime.datetime(1979, 5, 5, 6, 0),
#        datetime.datetime(1979, 5, 5, 12, 0),
#        datetime.datetime(1979, 5, 5, 18, 0),
#        datetime.datetime(1979, 5, 6, 0, 0),
#        datetime.datetime(1979, 5, 6, 6, 0),
#        datetime.datetime(1979, 5, 6, 12, 0),
#        datetime.datetime(1979, 5, 6, 18, 0),
#        datetime.datetime(1979, 5, 7, 0, 0),
#        datetime.datetime(1979, 5, 7, 6, 0),
#        datetime.datetime(1979, 5, 7, 12, 0),
#        datetime.datetime(1979, 5, 7, 18, 0),
#        datetime.datetime(1979, 5, 8, 0, 0),
#        datetime.datetime(1979, 5, 8, 6, 0),
#        datetime.datetime(1979, 5, 8, 12, 0),
#        datetime.datetime(1979, 5, 8, 18, 0),
#        datetime.datetime(1979, 5, 9, 0, 0),
#        datetime.datetime(1979, 5, 9, 6, 0),
#        datetime.datetime(1979, 5, 9, 12, 0),
#        datetime.datetime(1979, 5, 9, 18, 0),
#        datetime.datetime(1979, 5, 10, 0, 0),
#        datetime.datetime(1979, 5, 10, 6, 0),
#        datetime.datetime(1979, 5, 10, 12, 0),
#        datetime.datetime(1979, 5, 10, 18, 0),
#        datetime.datetime(1979, 5, 11, 0, 0),
#        datetime.datetime(1979, 5, 11, 6, 0),
#        datetime.datetime(1979, 5, 11, 12, 0),
#        datetime.datetime(1979, 5, 11, 18, 0),
#        datetime.datetime(1979, 5, 12, 0, 0),
#        datetime.datetime(1979, 5, 12, 6, 0),
#        datetime.datetime(1979, 5, 12, 12, 0),
#        datetime.datetime(1979, 5, 12, 18, 0),
#        datetime.datetime(1979, 5, 13, 0, 0),
#        datetime.datetime(1979, 5, 13, 6, 0),
#        datetime.datetime(1979, 5, 13, 12, 0),
#        datetime.datetime(1979, 5, 13, 18, 0),
#        datetime.datetime(1979, 5, 14, 0, 0),
#        datetime.datetime(1979, 5, 14, 6, 0),
#        datetime.datetime(1979, 5, 14, 12, 0),
#        datetime.datetime(1979, 5, 14, 18, 0),
#        datetime.datetime(1979, 5, 15, 0, 0),
#        datetime.datetime(1979, 5, 15, 6, 0),
#        datetime.datetime(1979, 5, 15, 12, 0),
#        datetime.datetime(1979, 5, 15, 18, 0),
#        datetime.datetime(1979, 5, 16, 0, 0),
#        datetime.datetime(1979, 5, 16, 6, 0),
#        datetime.datetime(1979, 5, 16, 12, 0),
#        datetime.datetime(1979, 5, 16, 18, 0),
#        datetime.datetime(1979, 5, 17, 0, 0),
#        datetime.datetime(1979, 5, 17, 6, 0),
#        datetime.datetime(1979, 5, 17, 12, 0),
#        datetime.datetime(1979, 5, 17, 18, 0),
#        datetime.datetime(1979, 5, 18, 0, 0),
#        datetime.datetime(1979, 5, 18, 6, 0),
#        datetime.datetime(1979, 5, 18, 12, 0),
#        datetime.datetime(1979, 5, 18, 18, 0),
#        datetime.datetime(1979, 5, 19, 0, 0),
#        datetime.datetime(1979, 5, 19, 6, 0),
#        datetime.datetime(1979, 5, 19, 12, 0),
#        datetime.datetime(1979, 5, 19, 18, 0),
#        datetime.datetime(1979, 5, 20, 0, 0),
#        datetime.datetime(1979, 5, 20, 6, 0),
#        datetime.datetime(1979, 5, 20, 12, 0),
#        datetime.datetime(1979, 5, 20, 18, 0),
#        datetime.datetime(1979, 5, 21, 0, 0),
#        datetime.datetime(1979, 5, 21, 6, 0),
#        datetime.datetime(1979, 5, 21, 12, 0),
#        datetime.datetime(1979, 5, 21, 18, 0),
#        datetime.datetime(1979, 5, 22, 0, 0),
#        datetime.datetime(1979, 5, 22, 6, 0),
#        datetime.datetime(1979, 5, 22, 12, 0),
#        datetime.datetime(1979, 5, 22, 18, 0),
#        datetime.datetime(1979, 5, 23, 0, 0),
#        datetime.datetime(1979, 5, 23, 6, 0),
#        datetime.datetime(1979, 5, 23, 12, 0),
#        datetime.datetime(1979, 5, 23, 18, 0),
#        datetime.datetime(1979, 5, 24, 0, 0),
#        datetime.datetime(1979, 5, 24, 6, 0),
#        datetime.datetime(1979, 5, 24, 12, 0),
#        datetime.datetime(1979, 5, 24, 18, 0),
#        datetime.datetime(1979, 5, 25, 0, 0),
#        datetime.datetime(1979, 5, 25, 6, 0),
#        datetime.datetime(1979, 5, 25, 12, 0),
#        datetime.datetime(1979, 5, 25, 18, 0),
#        datetime.datetime(1979, 5, 26, 0, 0),
#        datetime.datetime(1979, 5, 26, 6, 0),
#        datetime.datetime(1979, 5, 26, 12, 0),
#        datetime.datetime(1979, 5, 26, 18, 0),
#        datetime.datetime(1979, 5, 27, 0, 0),
#        datetime.datetime(1979, 5, 27, 6, 0),
#        datetime.datetime(1979, 5, 27, 12, 0),
#        datetime.datetime(1979, 5, 27, 18, 0),
#        datetime.datetime(1979, 5, 28, 0, 0),
#        datetime.datetime(1979, 5, 28, 6, 0),
#        datetime.datetime(1979, 5, 28, 12, 0),
#        datetime.datetime(1979, 5, 28, 18, 0),
#        datetime.datetime(1979, 5, 29, 0, 0),
#        datetime.datetime(1979, 5, 29, 6, 0),
#        datetime.datetime(1979, 5, 29, 12, 0),
#        datetime.datetime(1979, 5, 29, 18, 0),
#        datetime.datetime(1979, 5, 30, 0, 0),
#        datetime.datetime(1979, 5, 30, 6, 0),
#        datetime.datetime(1979, 5, 30, 12, 0),
#        datetime.datetime(1979, 5, 30, 18, 0),
#        datetime.datetime(1979, 5, 31, 0, 0),
#        datetime.datetime(1979, 5, 31, 6, 0),
#        datetime.datetime(1979, 5, 31, 12, 0),
#        datetime.datetime(1979, 5, 31, 18, 0),
#        datetime.datetime(1979, 6, 1, 0, 0),
#        datetime.datetime(1979, 6, 1, 6, 0),
#        datetime.datetime(1979, 6, 1, 12, 0),
#        datetime.datetime(1979, 6, 1, 18, 0),
#        datetime.datetime(1979, 6, 2, 0, 0),
#        datetime.datetime(1979, 6, 2, 6, 0),
#        datetime.datetime(1979, 6, 2, 12, 0),
#        datetime.datetime(1979, 6, 2, 18, 0),
#        datetime.datetime(1979, 6, 3, 0, 0),
#        datetime.datetime(1979, 6, 3, 6, 0),
#        datetime.datetime(1979, 6, 3, 12, 0),
#        datetime.datetime(1979, 6, 3, 18, 0),
#        datetime.datetime(1979, 6, 4, 0, 0),
#        datetime.datetime(1979, 6, 4, 6, 0),
#        datetime.datetime(1979, 6, 4, 12, 0),
#        datetime.datetime(1979, 6, 4, 18, 0),
#        datetime.datetime(1979, 6, 5, 0, 0),
#        datetime.datetime(1979, 6, 5, 6, 0),
#        datetime.datetime(1979, 6, 5, 12, 0),
#        datetime.datetime(1979, 6, 5, 18, 0),
#        datetime.datetime(1979, 6, 6, 0, 0),
#        datetime.datetime(1979, 6, 6, 6, 0),
#        datetime.datetime(1979, 6, 6, 12, 0),
#        datetime.datetime(1979, 6, 6, 18, 0),
#        datetime.datetime(1979, 6, 7, 0, 0),
#        datetime.datetime(1979, 6, 7, 6, 0),
#        datetime.datetime(1979, 6, 7, 12, 0),
#        datetime.datetime(1979, 6, 7, 18, 0),
#        datetime.datetime(1979, 6, 8, 0, 0),
#        datetime.datetime(1979, 6, 8, 6, 0),
#        datetime.datetime(1979, 6, 8, 12, 0),
#        datetime.datetime(1979, 6, 8, 18, 0),
#        datetime.datetime(1979, 6, 9, 0, 0),
#        datetime.datetime(1979, 6, 9, 6, 0),
#        datetime.datetime(1979, 6, 9, 12, 0),
#        datetime.datetime(1979, 6, 9, 18, 0),
#        datetime.datetime(1979, 6, 10, 0, 0),
#        datetime.datetime(1979, 6, 10, 6, 0),
#        datetime.datetime(1979, 6, 10, 12, 0),
#        datetime.datetime(1979, 6, 10, 18, 0),
#        datetime.datetime(1979, 6, 11, 0, 0),
#        datetime.datetime(1979, 6, 11, 6, 0),
#        datetime.datetime(1979, 6, 11, 12, 0),
#        datetime.datetime(1979, 6, 11, 18, 0),
#        datetime.datetime(1979, 6, 12, 0, 0),
#        datetime.datetime(1979, 6, 12, 6, 0),
#        datetime.datetime(1979, 6, 12, 12, 0),
#        datetime.datetime(1979, 6, 12, 18, 0),
#        datetime.datetime(1979, 6, 13, 0, 0),
#        datetime.datetime(1979, 6, 13, 6, 0),
#        datetime.datetime(1979, 6, 13, 12, 0),
#        datetime.datetime(1979, 6, 13, 18, 0),
#        datetime.datetime(1979, 6, 14, 0, 0),
#        datetime.datetime(1979, 6, 14, 6, 0),
#        datetime.datetime(1979, 6, 14, 12, 0),
#        datetime.datetime(1979, 6, 14, 18, 0),
#        datetime.datetime(1979, 6, 15, 0, 0),
#        datetime.datetime(1979, 6, 15, 6, 0),
#        datetime.datetime(1979, 6, 15, 12, 0),
#        datetime.datetime(1979, 6, 15, 18, 0),
#        datetime.datetime(1979, 6, 16, 0, 0),
#        datetime.datetime(1979, 6, 16, 6, 0),
#        datetime.datetime(1979, 6, 16, 12, 0),
#        datetime.datetime(1979, 6, 16, 18, 0),
#        datetime.datetime(1979, 6, 17, 0, 0),
#        datetime.datetime(1979, 6, 17, 6, 0),
#        datetime.datetime(1979, 6, 17, 12, 0),
#        datetime.datetime(1979, 6, 17, 18, 0),
#        datetime.datetime(1979, 6, 18, 0, 0),
#        datetime.datetime(1979, 6, 18, 6, 0),
#        datetime.datetime(1979, 6, 18, 12, 0),
#        datetime.datetime(1979, 6, 18, 18, 0),
#        datetime.datetime(1979, 6, 19, 0, 0),
#        datetime.datetime(1979, 6, 19, 6, 0),
#        datetime.datetime(1979, 6, 19, 12, 0),
#        datetime.datetime(1979, 6, 19, 18, 0),
#        datetime.datetime(1979, 6, 20, 0, 0),
#        datetime.datetime(1979, 6, 20, 6, 0),
#        datetime.datetime(1979, 6, 20, 12, 0),
#        datetime.datetime(1979, 6, 20, 18, 0),
#        datetime.datetime(1979, 6, 21, 0, 0),
#        datetime.datetime(1979, 6, 21, 6, 0),
#        datetime.datetime(1979, 6, 21, 12, 0),
#        datetime.datetime(1979, 6, 21, 18, 0),
#        datetime.datetime(1979, 6, 22, 0, 0),
#        datetime.datetime(1979, 6, 22, 6, 0),
#        datetime.datetime(1979, 6, 22, 12, 0),
#        datetime.datetime(1979, 6, 22, 18, 0),
#        datetime.datetime(1979, 6, 23, 0, 0),
#        datetime.datetime(1979, 6, 23, 6, 0),
#        datetime.datetime(1979, 6, 23, 12, 0),
#        datetime.datetime(1979, 6, 23, 18, 0),
#        datetime.datetime(1979, 6, 24, 0, 0),
#        datetime.datetime(1979, 6, 24, 6, 0),
#        datetime.datetime(1979, 6, 24, 12, 0),
#        datetime.datetime(1979, 6, 24, 18, 0),
#        datetime.datetime(1979, 6, 25, 0, 0),
#        datetime.datetime(1979, 6, 25, 6, 0),
#        datetime.datetime(1979, 6, 25, 12, 0),
#        datetime.datetime(1979, 6, 25, 18, 0),
#        datetime.datetime(1979, 6, 26, 0, 0),
#        datetime.datetime(1979, 6, 26, 6, 0),
#        datetime.datetime(1979, 6, 26, 12, 0),
#        datetime.datetime(1979, 6, 26, 18, 0),
#        datetime.datetime(1979, 6, 27, 0, 0),
#        datetime.datetime(1979, 6, 27, 6, 0),
#        datetime.datetime(1979, 6, 27, 12, 0),
#        datetime.datetime(1979, 6, 27, 18, 0),
#        datetime.datetime(1979, 6, 28, 0, 0),
#        datetime.datetime(1979, 6, 28, 6, 0),
#        datetime.datetime(1979, 6, 28, 12, 0),
#        datetime.datetime(1979, 6, 28, 18, 0),
#        datetime.datetime(1979, 6, 29, 0, 0),
#        datetime.datetime(1979, 6, 29, 6, 0),
#        datetime.datetime(1979, 6, 29, 12, 0),
#        datetime.datetime(1979, 6, 29, 18, 0),
#        datetime.datetime(1979, 6, 30, 0, 0),
#        datetime.datetime(1979, 6, 30, 6, 0),
#        datetime.datetime(1979, 6, 30, 12, 0),
#        datetime.datetime(1979, 6, 30, 18, 0),
#        datetime.datetime(1979, 7, 1, 0, 0),
#        datetime.datetime(1979, 7, 1, 6, 0),
#        datetime.datetime(1979, 7, 1, 12, 0),
#        datetime.datetime(1979, 7, 1, 18, 0),
#        datetime.datetime(1979, 7, 2, 0, 0),
#        datetime.datetime(1979, 7, 2, 6, 0),
#        datetime.datetime(1979, 7, 2, 12, 0),
#        datetime.datetime(1979, 7, 2, 18, 0),
#        datetime.datetime(1979, 7, 3, 0, 0),
#        datetime.datetime(1979, 7, 3, 6, 0),
#        datetime.datetime(1979, 7, 3, 12, 0),
#        datetime.datetime(1979, 7, 3, 18, 0),
#        datetime.datetime(1979, 7, 4, 0, 0),
#        datetime.datetime(1979, 7, 4, 6, 0),
#        datetime.datetime(1979, 7, 4, 12, 0),
#        datetime.datetime(1979, 7, 4, 18, 0),
#        datetime.datetime(1979, 7, 5, 0, 0),
#        datetime.datetime(1979, 7, 5, 6, 0),
#        datetime.datetime(1979, 7, 5, 12, 0),
#        datetime.datetime(1979, 7, 5, 18, 0),
#        datetime.datetime(1979, 7, 6, 0, 0),
#        datetime.datetime(1979, 7, 6, 6, 0),
#        datetime.datetime(1979, 7, 6, 12, 0),
#        datetime.datetime(1979, 7, 6, 18, 0),
#        datetime.datetime(1979, 7, 7, 0, 0),
#        datetime.datetime(1979, 7, 7, 6, 0),
#        datetime.datetime(1979, 7, 7, 12, 0),
#        datetime.datetime(1979, 7, 7, 18, 0),
#        datetime.datetime(1979, 7, 8, 0, 0),
#        datetime.datetime(1979, 7, 8, 6, 0),
#        datetime.datetime(1979, 7, 8, 12, 0),
#        datetime.datetime(1979, 7, 8, 18, 0),
#        datetime.datetime(1979, 7, 9, 0, 0),
#        datetime.datetime(1979, 7, 9, 6, 0),
#        datetime.datetime(1979, 7, 9, 12, 0),
#        datetime.datetime(1979, 7, 9, 18, 0),
#        datetime.datetime(1979, 7, 10, 0, 0),
#        datetime.datetime(1979, 7, 10, 6, 0),
#        datetime.datetime(1979, 7, 10, 12, 0),
#        datetime.datetime(1979, 7, 10, 18, 0),
#        datetime.datetime(1979, 7, 11, 0, 0),
#        datetime.datetime(1979, 7, 11, 6, 0),
#        datetime.datetime(1979, 7, 11, 12, 0),
#        datetime.datetime(1979, 7, 11, 18, 0),
#        datetime.datetime(1979, 7, 12, 0, 0),
#        datetime.datetime(1979, 7, 12, 6, 0),
#        datetime.datetime(1979, 7, 12, 12, 0),
#        datetime.datetime(1979, 7, 12, 18, 0),
#        datetime.datetime(1979, 7, 13, 0, 0),
#        datetime.datetime(1979, 7, 13, 6, 0),
#        datetime.datetime(1979, 7, 13, 12, 0),
#        datetime.datetime(1979, 7, 13, 18, 0),
#        datetime.datetime(1979, 7, 14, 0, 0),
#        datetime.datetime(1979, 7, 14, 6, 0),
#        datetime.datetime(1979, 7, 14, 12, 0),
#        datetime.datetime(1979, 7, 14, 18, 0),
#        datetime.datetime(1979, 7, 15, 0, 0),
#        datetime.datetime(1979, 7, 15, 6, 0),
#        datetime.datetime(1979, 7, 15, 12, 0),
#        datetime.datetime(1979, 7, 15, 18, 0),
#        datetime.datetime(1979, 7, 16, 0, 0),
#        datetime.datetime(1979, 7, 16, 6, 0),
#        datetime.datetime(1979, 7, 16, 12, 0),
#        datetime.datetime(1979, 7, 16, 18, 0),
#        datetime.datetime(1979, 7, 17, 0, 0),
#        datetime.datetime(1979, 7, 17, 6, 0),
#        datetime.datetime(1979, 7, 17, 12, 0),
#        datetime.datetime(1979, 7, 17, 18, 0),
#        datetime.datetime(1979, 7, 18, 0, 0),
#        datetime.datetime(1979, 7, 18, 6, 0),
#        datetime.datetime(1979, 7, 18, 12, 0),
#        datetime.datetime(1979, 7, 18, 18, 0),
#        datetime.datetime(1979, 7, 19, 0, 0),
#        datetime.datetime(1979, 7, 19, 6, 0),
#        datetime.datetime(1979, 7, 19, 12, 0),
#        datetime.datetime(1979, 7, 19, 18, 0),
#        datetime.datetime(1979, 7, 20, 0, 0),
#        datetime.datetime(1979, 7, 20, 6, 0),
#        datetime.datetime(1979, 7, 20, 12, 0),
#        datetime.datetime(1979, 7, 20, 18, 0),
#        datetime.datetime(1979, 7, 21, 0, 0),
#        datetime.datetime(1979, 7, 21, 6, 0),
#        datetime.datetime(1979, 7, 21, 12, 0),
#        datetime.datetime(1979, 7, 21, 18, 0),
#        datetime.datetime(1979, 7, 22, 0, 0),
#        datetime.datetime(1979, 7, 22, 6, 0),
#        datetime.datetime(1979, 7, 22, 12, 0),
#        datetime.datetime(1979, 7, 22, 18, 0),
#        datetime.datetime(1979, 7, 23, 0, 0),
#        datetime.datetime(1979, 7, 23, 6, 0),
#        datetime.datetime(1979, 7, 23, 12, 0),
#        datetime.datetime(1979, 7, 23, 18, 0),
#        datetime.datetime(1979, 7, 24, 0, 0),
#        datetime.datetime(1979, 7, 24, 6, 0),
#        datetime.datetime(1979, 7, 24, 12, 0),
#        datetime.datetime(1979, 7, 24, 18, 0),
#        datetime.datetime(1979, 7, 25, 0, 0),
#        datetime.datetime(1979, 7, 25, 6, 0),
#        datetime.datetime(1979, 7, 25, 12, 0),
#        datetime.datetime(1979, 7, 25, 18, 0),
#        datetime.datetime(1979, 7, 26, 0, 0),
#        datetime.datetime(1979, 7, 26, 6, 0),
#        datetime.datetime(1979, 7, 26, 12, 0),
#        datetime.datetime(1979, 7, 26, 18, 0),
#        datetime.datetime(1979, 7, 27, 0, 0),
#        datetime.datetime(1979, 7, 27, 6, 0),
#        datetime.datetime(1979, 7, 27, 12, 0),
#        datetime.datetime(1979, 7, 27, 18, 0),
#        datetime.datetime(1979, 7, 28, 0, 0),
#        datetime.datetime(1979, 7, 28, 6, 0),
#        datetime.datetime(1979, 7, 28, 12, 0),
#        datetime.datetime(1979, 7, 28, 18, 0),
#        datetime.datetime(1979, 7, 29, 0, 0),
#        datetime.datetime(1979, 7, 29, 6, 0),
#        datetime.datetime(1979, 7, 29, 12, 0),
#        datetime.datetime(1979, 7, 29, 18, 0),
#        datetime.datetime(1979, 7, 30, 0, 0),
#        datetime.datetime(1979, 7, 30, 6, 0),
#        datetime.datetime(1979, 7, 30, 12, 0),
#        datetime.datetime(1979, 7, 30, 18, 0),
#        datetime.datetime(1979, 7, 31, 0, 0),
#        datetime.datetime(1979, 7, 31, 6, 0),
#        datetime.datetime(1979, 7, 31, 12, 0),
#        datetime.datetime(1979, 7, 31, 18, 0)], dtype=object)
