# %% [markdown]
# # Occurrence frequencies of IVT object for regional control ICON experiment forced by CNMR (1984-2014)

# %%
# %load_ext autoreload
# %autoreload 2
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import datetime
import cartopy
from metpy.units import units
import cartopy.crs as ccrs
import pickle
import os

from src.utils import load_pkl, create_datetime_lists, get_datetime_str, count_objs_grid_points 
from src.Enumerations import Month, Season, Experiments, GPH700_4Cluster, Domains
from src.xarray_util import create_obj_from_dict,  ObjectContainer,  load_tracking_objects
from src.plot_funcs import plot_unstructured_rotated_grid
# Out:
# /work/aa0238/a271093/Conda/MOAAP_env/lib/python3.12/site-packages/pyproj/__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()
# /work/aa0238/a271093/Scripts/MOAAP/src/xarray_util.py:15: AccessorRegistrationWarning: registration of accessor <class 'src.xarray_util.Accessor'> under name 'get' for type <class 'xarray.core.dataset.Dataset'> is overriding a preexisting attribute with the same name.
#   @xr.register_dataset_accessor("get")

# %% [markdown]
# ## Settings

# %%
exp_CNRM=Experiments.ICON_CNRM_CONTROL.value
exp_ERA5=Experiments.ERA5.value

input_path_ERA5= exp_ERA5.path_IVT_tracking
input_path_CNRM= exp_CNRM.path_IVT_tracking


type_='IVT'
input_file_name_temp_ERA5 = 'MOAPP_ERA5_100and85controlperc_remapped_3x'
input_file_name_temp_CNRM = 'MOAPP_ICON_100and85controlperc_remapped_3x'

first_year = 1984
last_year = 1985
num_years = last_year-first_year

# %% [markdown]
# ## Load pickle dictionaries into in-memory Datasets

# %%
IVT_objs_CNRM = load_tracking_objects(input_path_CNRM, input_file_name_temp_CNRM, type_, first_year, last_year,load_coordinates=True, exp=exp_CNRM,save_pkl=True)

IVT_objs_ERA5 = load_tracking_objects(input_path_ERA5, input_file_name_temp_ERA5, type_, first_year, last_year,load_coordinates=True,exp=exp_ERA5,save_pkl=True)
# Out:
# 1984-01-01 00:00:00
# 1984-07-01 00:00:00
# 1985-01-01 00:00:00
# 1985-07-01 00:00:00
# 1986-01-01 00:00:00
# 1986-07-01 00:00:00
# 1987-01-01 00:00:00
# 1987-07-01 00:00:00
# 1988-01-01 00:00:00
# 1988-07-01 00:00:00
# 1989-01-01 00:00:00
# 1989-07-01 00:00:00
# 1990-01-01 00:00:00
# 1990-07-01 00:00:00
# 1991-01-01 00:00:00
# 1991-07-01 00:00:00
# 1992-01-01 00:00:00
# 1992-07-01 00:00:00
# 1993-01-01 00:00:00
# 1993-07-01 00:00:00
# 1994-01-01 00:00:00
# 1994-07-01 00:00:00
# 1995-01-01 00:00:00
# 1995-07-01 00:00:00
# 1996-01-01 00:00:00
# 1996-07-01 00:00:00
# 1997-01-01 00:00:00
# 1997-07-01 00:00:00
# 1998-01-01 00:00:00
# 1998-07-01 00:00:00
# 1999-01-01 00:00:00
# 1999-07-01 00:00:00
# 2000-01-01 00:00:00
# 2000-07-01 00:00:00
# 2001-01-01 00:00:00
# 2001-07-01 00:00:00
# 2002-01-01 00:00:00
# 2002-07-01 00:00:00
# 2003-01-01 00:00:00
# 2003-07-01 00:00:00
# 2004-01-01 00:00:00
# 2004-07-01 00:00:00
# 2005-01-01 00:00:00
# 2005-07-01 00:00:00
# 2006-01-01 00:00:00
# 2006-07-01 00:00:00
# 2007-01-01 00:00:00
# 2007-07-01 00:00:00
# 2008-01-01 00:00:00
# 2008-07-01 00:00:00
# 2009-01-01 00:00:00
# 2009-07-01 00:00:00
# 2010-01-01 00:00:00
# 2010-07-01 00:00:00
# 2011-01-01 00:00:00
# 2011-07-01 00:00:00
# 1984-01-01 00:00:00
# 1984-07-01 00:00:00
# 1985-01-01 00:00:00
# 1985-07-01 00:00:00
# 1986-01-01 00:00:00
# 1986-07-01 00:00:00
# 1987-01-01 00:00:00
# 1987-07-01 00:00:00
# 1988-01-01 00:00:00
# 1988-07-01 00:00:00
# 1989-01-01 00:00:00
# 1989-07-01 00:00:00
# 1990-01-01 00:00:00
# 1990-07-01 00:00:00
# 1991-01-01 00:00:00
# 1991-07-01 00:00:00
# 1992-01-01 00:00:00
# 1992-07-01 00:00:00
# 1993-01-01 00:00:00
# 1993-07-01 00:00:00
# 1994-01-01 00:00:00
# 1994-07-01 00:00:00
# 1995-01-01 00:00:00
# 1995-07-01 00:00:00
# 1996-01-01 00:00:00
# 1996-07-01 00:00:00
# 1997-01-01 00:00:00
# 1997-07-01 00:00:00
# 1998-01-01 00:00:00
# 1998-07-01 00:00:00
# 1999-01-01 00:00:00
# 1999-07-01 00:00:00
# 2000-01-01 00:00:00
# 2000-07-01 00:00:00
# 2001-01-01 00:00:00
# 2001-07-01 00:00:00
# 2002-01-01 00:00:00
# 2002-07-01 00:00:00
# 2003-01-01 00:00:00
# 2003-07-01 00:00:00
# 2004-01-01 00:00:00
# 2004-07-01 00:00:00
# 2005-01-01 00:00:00
# 2005-07-01 00:00:00
# 2006-01-01 00:00:00
# 2006-07-01 00:00:00
# 2007-01-01 00:00:00
# 2007-07-01 00:00:00
# 2008-01-01 00:00:00
# 2008-07-01 00:00:00
# 2009-01-01 00:00:00
# 2009-07-01 00:00:00
# 2010-01-01 00:00:00
# 2010-07-01 00:00:00
# 2011-01-01 00:00:00
# 2011-07-01 00:00:00

# %%
fig = plt.figure(figsize=(20,10))
subplts = (2,4)
levels=np.arange(0,10,1)
for   i, regime in enumerate(GPH700_4Cluster):
    
    regime= regime.value
    print (regime)
        
    IVTobjs_sel_ERA5 = IVT_objs_ERA5.sel_season(Season.DJF).sel_by_regime(regime)

    lon,lat,z = count_objs_grid_points(IVTobjs_sel_ERA5, normalization_factor=24.)
    
    # normalize grid point counts to counts per season
    z= (z/num_years)*1.000001
    
    plot_unstructured_rotated_grid(lon,
                                  lat, 
                                  z, 
                                  fig=fig,
                                  index = i,
                                  subplts=subplts,
 
                                  levels = levels,
                                  title=f"ERA5: {regime} in DJF",
                                  cbar_label = "IVT object days per season",)
    

    IVTobjs_sel_CNRM = IVT_objs_CNRM.sel_season(Season.DJF).sel_by_regime(regime)

    lon,lat,z = count_objs_grid_points(IVTobjs_sel_CNRM, normalization_factor=24.)
    
    # normalize grid point counts to counts per season
    z= (z/num_years)*1.000001
    
    plot_unstructured_rotated_grid(lon,
                                  lat, 
                                  z, 
                                  fig=fig,
                                  index = i+4,
                                  subplts=subplts,
 
                                  levels = levels,
                                  title=f"CNRM: {regime} in DJF",
                                  cbar_label = "IVT object days per season",)
plt.tight_layout()
# Out:
# NAO+
# NAO-
# ATL-
# SCAN

# %%
fig = plt.figure(figsize=(20,10))
subplts = (2,4)
levels=np.arange(0,4,0.5)
for   i, regime in enumerate(GPH700_4Cluster):
    
    regime= regime.value
    print (regime)
        
    IVTobjs_sel_ERA5 = IVT_objs_ERA5.sel_season(Season.DJF).sel_by_regime(regime).seltimesteps(slice(0,1))

    lon,lat,z = count_objs_grid_points(IVTobjs_sel_ERA5, normalization_factor=1)
    
    # normalize grid point counts to counts per season
    z= (z/num_years)*1.000001
    
    plot_unstructured_rotated_grid(lon,
                                  lat, 
                                  z, 
                                  fig=fig,
                                  index = i,
                                  subplts=subplts,
 
                                  levels = levels,
                                  title=f"ERA5: {regime} in DJF",
                                  cbar_label = "IVT object origins per season",
                                  )
    

    IVTobjs_sel_CNRM = IVT_objs_CNRM.sel_season(Season.DJF).sel_by_regime(regime).seltimesteps(slice(0,1))

    lon,lat,z = count_objs_grid_points(IVTobjs_sel_CNRM, normalization_factor=1)
    
    # normalize grid point counts to counts per season
    z= (z/num_years)*1.000001
    
    plot_unstructured_rotated_grid(lon,
                                  lat, 
                                  z, 
                                  fig=fig,
                                  index = i+4,
                                  subplts=subplts,
 
                                  levels = levels,
                                  title=f"CNRM: {regime} in DJF",
                                  cbar_label = "IVT object origins per season",
                                  )
plt.tight_layout()
# Out:
# NAO+
# NAO-
# ATL-
# SCAN

# %%
print (season_)
    
        
    IVTobjs_sel_CNRM = IVT_objs_CNRM.sel_season(season_).sel_by_domain(Domains.NORTH_ATLANTIC).seltimesteps(slice(-1,None))

    lon,lat,z = count_objs_grid_points(IVTobjs_sel_CNRM, normalization_factor=1)
    
    # normalize grid point counts to counts per season
    z= (z/num_years)*1.000001
    
    plot_unstructured_rotated_grid(lon,
                                  lat, 
                                  z, 
                                  fig=fig,
                                  index = i,
                                  subplts=subplts,
 
                                  levels = levels,
                                  title="CNRM_control: "+season_.name,
                                  cbar_label = "IVT objects endpoint per season",
                                  plot_domains={Domains.NORTH_ATLANTIC : 'green'})
        
    IVTobjs_sel_ERA5 = IVT_objs_ERA5.sel_season(season_).sel_by_domain(Domains.NORTH_ATLANTIC).seltimesteps(slice(-1,None))

    lon,lat,z = count_objs_grid_points(IVTobjs_sel_ERA5, normalization_factor=1)
    
    # normalize grid point counts to counts per season
    z= (z/num_years)*1.000001
    
    plot_unstructured_rotated_grid(lon,
                                  lat, 
                                  z, 
                                  fig=fig,
                                  index = i+1 ,
                                  levels = levels,
                                   subplts=subplts,
                                  title='ERA5: '+ season_.name,
                                  cbar_label = "IVT objects endpoint per season",
                                  plot_domains={Domains.NORTH_ATLANTIC : 'green'})
